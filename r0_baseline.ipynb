# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from lifelines import CoxPHFitter
from lifelines.utils import k_fold_cross_validation
from lifelines.utils import survival_events_from_table
from lifelines import KaplanMeierFitter
import seaborn as sns

# %%
survival = pd.read_csv("C:/Users/Atmaja/Desktop/r0_baseline_new.csv")

# %%
survival.head()
# Out:
#     pid   age  gender     ht     wt        bmi   ps       alb  bili  \
# 0  821L  65.0     1.0  1.727   63.3  21.223599  1.0  39.84681   0.8
# 1  831L  62.0     2.0  1.676  102.7  36.561366  0.0  39.84681   0.4
# 2  835L  48.0     1.0  1.829   85.0  25.409231  0.0  39.84681   1.4
# 3  845L  52.0     2.0  1.676  103.4  36.810567  1.0  39.84681   1.1
# 4  860L  60.0     1.0  1.803  103.6  31.868990  1.0  39.84681   0.7
#
#          hgb  ...   target  egfr  protocolnum  conf_stat   br_stat  ttp_time  \
# 0   9.800000  ...        0     0            2    0.31218  0.485149  1.051335
# 1  11.400000  ...        0     0            2    0.31218  0.485149  1.839836
# 2  12.100000  ...        0     0            2    0.31218  0.485149  0.361396
# 3  13.500000  ...        0     0            2    0.31218  0.485149  1.971253
# 4  14.438144  ...        0     0            2    0.31218  0.485149  1.741273
#
#     os_time  os_stat  max_grade_all   arm
# 0  3.022587        1            3.0  2.02
# 1  5.880903        1            3.0  2.02
# 2  0.361396        1            3.0  2.02
# 3  8.574949        1            2.0  2.02
# 4  2.431211        1            4.0  2.02
#
# [5 rows x 45 columns]

# %%
df = pd.DataFrame(survival)
#df.drop(df.columns[[0]], axis=1, inplace=True)  

survival['os_stat'] = survival.os_stat.astype(float)        #change datatype
survival['os_stat'].dtype

survival['gender'] = survival.gender.astype(float)        #change datatype
survival['gender'].dtype

survival['protocolnum'] = survival.protocolnum.astype(float)        #change datatype
survival['protocolnum'].dtype

del df['ang']         
del df['pid'] 
del df['target'] 
del df['egfr']         #delete 'ang','target','pid','egfr'
survival.dtypes
# Out:
# age              float64
# gender           float64
# ht               float64
# wt               float64
# bmi              float64
# ps               float64
# alb              float64
# bili             float64
# hgb              float64
# plt              float64
# wbc              float64
# anc              float64
# ldh              float64
# alk              float64
# cea              float64
# mindia           float64
# maxdia           float64
# sumdia           float64
# numtumors        float64
# braf             float64
# kras             float64
# rectum           float64
# colon            float64
# ln               float64
# peritoneal       float64
# lung             float64
# liver            float64
# rt               float64
# surg             float64
# surg_met         float64
# resect_pt        float64
# surg_pt          float64
# chemo            float64
# protocolnum      float64
# conf_stat        float64
# br_stat          float64
# ttp_time         float64
# os_time          float64
# os_stat          float64
# max_grade_all    float64
# arm              float64
# dtype: object

# %%
cph = CoxPHFitter()
cph.fit(survival, duration_col='os_time', event_col='os_stat', show_progress=True)#same values for 0.1,0.5 stpsize only no.of step vary
cph.print_summary()
# Out:
# Iteration 1: norm_delta = 9.73215, step_size = 0.95000, ll = -89020.96896, newton_decrement = 1982.44561, seconds_since_start = 2.9
# Iteration 2: norm_delta = 0.88141, step_size = 0.71250, ll = -87043.91544, newton_decrement = 505.65916, seconds_since_start = 5.8
# Iteration 3: norm_delta = 2.98127, step_size = 0.85500, ll = -86531.80237, newton_decrement = 194.76511, seconds_since_start = 9.1
# Iteration 4: norm_delta = 1.92716, step_size = 0.93100, ll = -86326.46438, newton_decrement = 19.45807, seconds_since_start = 12.7
# Iteration 5: norm_delta = 0.27950, step_size = 0.93100, ll = -86306.55168, newton_decrement = 0.27690, seconds_since_start = 16.1
# Iteration 6: norm_delta = 0.02178, step_size = 0.95000, ll = -86306.27519, newton_decrement = 0.00155, seconds_since_start = 19.3
# Iteration 7: norm_delta = 0.00110, step_size = 0.95000, ll = -86306.27365, newton_decrement = 0.00000, seconds_since_start = 22.6
# Convergence completed after 7 iterations.
# <lifelines.CoxPHFitter: fitted with 12988 observations, 2667 censored>
#       duration col = os_time
#          event col = os_stat
# number of subjects = 12988
#   number of events = 10321
#     log-likelihood = -86306.274
#   time fit was run = 2018-12-13 11:16:48 UTC
#
# ---
#                  coef  exp(coef)  se(coef)        z      p  lower 0.95  upper 0.95
# age            0.0080     1.0081    0.0010   7.9084 0.0000      0.0060      0.0100  ***
# gender        -0.0644     0.9376    0.0269  -2.3967 0.0165     -0.1171     -0.0117    .
# ht             0.3081     1.3608    0.2455   1.2550 0.2095     -0.1730      0.7892
# wt            -0.0063     0.9937    0.0024  -2.5785 0.0099     -0.0111     -0.0015    *
# bmi            0.0072     1.0072    0.0072   0.9936 0.3204     -0.0070      0.0214
# ps             0.2908     1.3375    0.0171  16.9829 0.0000      0.2573      0.3244  ***
# alb            0.0003     1.0003    0.0008   0.3335 0.7387     -0.0013      0.0019
# bili           0.0374     1.0381    0.0084   4.4511 0.0000      0.0209      0.0539  ***
# hgb           -0.0001     0.9999    0.0006  -0.2191 0.8266     -0.0012      0.0010
# plt            0.0011     1.0011    0.0001  13.2030 0.0000      0.0009      0.0013  ***
# wbc            0.0002     1.0002    0.0002   0.8886 0.3742     -0.0002      0.0006
# anc            0.0000     1.0000    0.0000   2.4894 0.0128      0.0000      0.0000    .
# ldh            0.0001     1.0001    0.0000   6.4856 0.0000      0.0001      0.0002  ***
# alk            0.0008     1.0008    0.0001  12.9854 0.0000      0.0007      0.0010  ***
# cea           -0.0000     1.0000    0.0000  -0.8550 0.3926     -0.0000      0.0000
# mindia        -0.0002     0.9998    0.0007  -0.2006 0.8410     -0.0016      0.0013
# maxdia         0.0007     1.0007    0.0006   1.2447 0.2132     -0.0004      0.0018
# sumdia         0.0007     1.0007    0.0001   5.8030 0.0000      0.0005      0.0009  ***
# numtumors      0.0113     1.0114    0.0068   1.6655 0.0958     -0.0020      0.0246
# braf           0.5394     1.7149    0.0815   6.6178 0.0000      0.3796      0.6991  ***
# kras           0.0570     1.0587    0.0359   1.5905 0.1117     -0.0132      0.1273
# rectum         0.0570     1.0587    0.0738   0.7719 0.4402     -0.0877      0.2017
# colon          0.1394     1.1496    0.0719   1.9392 0.0525     -0.0015      0.2804
# ln             0.0712     1.0738    0.0135   5.2906 0.0000      0.0448      0.0976  ***
# peritoneal     0.1314     1.1404    0.0192   6.8398 0.0000      0.0937      0.1690  ***
# lung           0.0179     1.0181    0.0136   1.3158 0.1883     -0.0088      0.0447
# liver          0.0823     1.0858    0.0164   5.0231 0.0000      0.0502      0.1144  ***
# rt             0.1509     1.1628    0.0438   3.4473 0.0006      0.0651      0.2366   **
# surg          -0.3630     0.6956    0.0681  -5.3268 0.0000     -0.4965     -0.2294  ***
# surg_met      -0.2932     0.7459    0.0601  -4.8815 0.0000     -0.4109     -0.1755  ***
# resect_pt     -0.1640     0.8488    0.0500  -3.2819 0.0010     -0.2619     -0.0661    *
# surg_pt        0.1080     1.1140    0.0774   1.3956 0.1628     -0.0437      0.2596
# chemo          0.0656     1.0678    0.0297   2.2086 0.0272      0.0074      0.1238    .
# protocolnum    1.2340     3.4351    0.5149   2.3968 0.0165      0.2249      2.2432    .
# conf_stat     -0.1909     0.8262    0.0390  -4.8979 0.0000     -0.2673     -0.1145  ***
# br_stat       -0.2962     0.7436    0.0348  -8.5019 0.0000     -0.3645     -0.2279  ***
# ttp_time      -0.1113     0.8947    0.0026 -42.6212 0.0000     -0.1164     -0.1062  ***
# max_grade_all  0.1408     1.1512    0.0185   7.6251 0.0000      0.1046      0.1769  ***
# arm           -1.2325     0.2916    0.5153  -2.3919 0.0168     -2.2424     -0.2226    .
# ---
# Signif. codes: 0 '***' 0.0001 '**' 0.001 '*' 0.01 '.' 0.05 ' ' 1
#
# Concordance = 0.739
# Likelihood ratio test = 5429.391 on 39 df, p=0.00000

# %%
X = survival.drop(["os_time", "os_stat"], axis=1)
cph.predict_partial_hazard(X)
cph.predict_survival_function(X)
cph.predict_survival_function(X, times=[5., 25., 50.])
# Out:
#              0         1             2             3             4      \
# 5.0   4.568509e-01  0.865394  6.818841e-01  6.572449e-01  6.762526e-01
# 25.0  1.277091e-05  0.124994  4.056068e-03  2.388927e-03  3.599977e-03
# 50.0  6.080289e-14  0.003640  3.471198e-07  8.310128e-08  2.515208e-07
#
#          5         6         7         8         9        ...        12978  \
# 5.0   0.802994  0.885451  0.943553  0.858656  0.792321    ...     0.904012
# 25.0  0.042598  0.173787  0.433554  0.111701  0.035140    ...     0.234214
# 50.0  0.000199  0.008863  0.104665  0.002687  0.000118    ...     0.019842
#
#          12979     12980     12981     12982     12983     12984     12985  \
# 5.0   0.922302  0.874833  0.811517  0.951681  0.823729  0.919701  0.939288
# 25.0  0.312421  0.146102  0.049584  0.490483  0.061468  0.299984  0.406197
# 50.0  0.043202  0.005547  0.000300  0.146051  0.000535  0.038713  0.087773
#
#          12986     12987
# 5.0   0.941866  0.952588
# 25.0  0.422532  0.497249
# 50.0  0.097634  0.151555
#
# [3 rows x 12988 columns]

# %%
cph = CoxPHFitter()
scores = k_fold_cross_validation(cph, survival, 'os_time', event_col='os_stat', k=3)
print(scores)
print(np.mean(scores))
print(np.std(scores))       #k fold cross validation evaluates on testing set using concordance measure
# Out:
# [0.7381108052241596, 0.7400017812209203, 0.7330183488365088]
# 0.737043645093863
# 0.0029491473371900585

# %%
cph.plot()   #plot of variables with the range

# %%
cph.plot_covariate_groups('numtumors', [0, 50, 100, 150]) #varies one variable keeping rest constant with time

# %%
d_0 = df.loc[df['gender'] == 1]
d_1 = df.loc[df['gender'] == 2]

kmf0 = KaplanMeierFitter()
kmf0.fit(d_0['os_time'], event_observed=d_0['os_stat'])

kmf1 = KaplanMeierFitter()
kmf1.fit(d_1['os_time'], event_observed=d_1['os_stat'])

fig, axes = plt.subplots()
kmf0.plot_loglogs(ax=axes)
kmf1.plot_loglogs(ax=axes)
axes.legend([1, 2])

plt.show()                          #doesnt follow propotional hazard assmpt

# %%
d_0 = df.loc[df['surg'] == 0]
d_1 = df.loc[df['surg'] == 1]

kmf0 = KaplanMeierFitter()
kmf0.fit(d_0['os_time'], event_observed=d_0['os_stat'])

kmf1 = KaplanMeierFitter()
kmf1.fit(d_1['os_time'], event_observed=d_1['os_stat'])

fig, axes = plt.subplots()
kmf0.plot_loglogs(ax=axes)
kmf1.plot_loglogs(ax=axes)
axes.legend([0, 1])

plt.show()                         #doesnt follow proportional hazard assmpt

# %%
corrmat=survival.corr()
f,ax=plt.subplots(figsize=(10,10))
sns.heatmap(corrmat,square=True)
